# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

img = Image.open("Dr_Shashi_Tharoor.jpg")
plt.imshow(img)
plt.title("Dr Shashi Tharoor Image")
plt.show()
print("Image loaded successfully!")
# Out:
# Image loaded successfully!
